# %% [markdown]
# # Access an ASAM ODS EXD-API Plugin

# %% [markdown]
# ## Prepare Python Environment to Access GRPC Service

# %%
try:
    import ods_external_data_pb2_grpc as ods_external_data_pb2_grpc_check_import
except:
    # !python -m pip install --upgrade pip
    # !python -m pip install grpcio
    # !python -m pip install grpcio-tools
    ## To update stubs download protos and run this lines
    # !python -m grpc_tools.protoc --proto_path=. --pyi_out=. --python_out=. ods.proto
    # !python -m grpc_tools.protoc -I. --pyi_out=. --python_out=. --grpc_python_out=. ods_external_data.proto

# %%
import os
import pathlib

import grpc
from google.protobuf.json_format import MessageToJson

import ods_pb2
import ods_external_data_pb2
import ods_external_data_pb2_grpc

# %% [markdown]
# ## EXD-API
#
# The EXD-API plugin is running as a RPC service at a given URL.
# Running `exd_api_server.py`´will run the plugin at the given URL.

# %%
exd_api_plugin_url = "localhost:50051"

# %% [markdown]
# ## Import Phase
#
# We will open a file using the EXD-API and extract the internal structure of the file to import it into the ASAM ODS server.

# %%
data_file_path = os.path.abspath("data/data_02.dxd")
if not os.path.exists(data_file_path):
    raise Exception("Data file is missing")

# %%
import_file_url = pathlib.Path(data_file_path).as_uri()
import_file_parameters = ""
print(import_file_url)

# Will be filled from Structure
access_file_url = None
access_file_parameters = None
# Out:
# file:///workspaces/asam_ods_exd_api_dewesoft/data/data_02.dxd

# %% [markdown]
# ### Extract Infos from Structure
#
# The structure contains infos about groups and channels to create corresponding measurements, submatrices and measurement_quantities

# %%
with grpc.insecure_channel(exd_api_plugin_url) as channel:
    stub = ods_external_data_pb2_grpc.ExternalDataReaderStub(channel)

    # import file into ASAM ODS Server physical storage
    import_identifier = ods_external_data_pb2.Identifier(url=import_file_url, parameters=import_file_parameters)

    import_handle = stub.Open(import_identifier)
    try:
        structure = stub.GetStructure(ods_external_data_pb2.StructureRequest(handle=import_handle))
        print(MessageToJson(structure))

        access_file_url = structure.identifier.url
        access_file_parameters = structure.identifier.parameters

        for group in structure.groups:
            group_id = group.id
            for channel in group.channels:
                channel_id = channel.id
    finally:
        stub.Close(import_handle)
# Out:
# {
#   "identifier": {
#     "url": "file:///workspaces/asam_ods_exd_api_dewesoft/data/data_02.dxd"
#   },
#   "name": "data_02.dxd",
#   "groups": [
#     {
#       "name": "AI:30000",
#       "totalNumberOfChannels": "8",
#       "numberOfRows": "30000",
#       "channels": [
#         {
#           "name": "Independent",
#           "dataType": "DT_DOUBLE",
#           "unitString": " ",
#           "attributes": {
#             "variables": {
#               "description": {
#                 "stringArray": {
#                   "values": [
#                     "Independent"
#                   ]
#                 }
#               },
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     1
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "1",
#           "name": "U_weight1",
#           "dataType": "DT_DOUBLE",
#           "unitString": "mV",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "2",
#           "name": "S_weight1",
#           "dataType": "DT_DOUBLE",
#           "unitString": "mV",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "3",
#           "name": "U_weight2",
#           "dataType": "DT_DOUBLE",
#           "unitString": "mV",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "4",
#           "name": "S_weight2",
#           "dataType": "DT_DOUBLE",
#           "unitString": "mV",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "5",
#           "name": "U_weight3",
#           "dataType": "DT_DOUBLE",
#           "unitString": "mV",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "6",
#           "name": "S_weight3",
#           "dataType": "DT_DOUBLE",
#           "unitString": "mV",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "7",
#           "name": "I_baron1",
#           "dataType": "DT_DOUBLE",
#           "unitString": "A",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         }
#       ]
#     },
#     {
#       "id": "1",
#       "name": "Plugins:30",
#       "totalNumberOfChannels": "5",
#       "numberOfRows": "30",
#       "channels": [
#         {
#           "name": "Independent",
#           "dataType": "DT_DOUBLE",
#           "unitString": " ",
#           "attributes": {
#             "variables": {
#               "description": {
#                 "stringArray": {
#                   "values": [
#                     "Independent"
#                   ]
#                 }
#               },
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     1
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "1",
#           "name": "Mass_wet",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "description": {
#                 "stringArray": {
#                   "values": [
#                     "Soil mass wet"
#                   ]
#                 }
#               },
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "2",
#           "name": "Mass_dry",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "description": {
#                 "stringArray": {
#                   "values": [
#                     "Soil mass dry"
#                   ]
#                 }
#               },
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "3",
#           "name": "Volume_tot",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "description": {
#                 "stringArray": {
#                   "values": [
#                     "Total volume in Baron"
#                   ]
#                 }
#               },
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "4",
#           "name": "Takt_time",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "description": {
#                 "stringArray": {
#                   "values": [
#                     "Takt time"
#                   ]
#                 }
#               },
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         }
#       ]
#     },
#     {
#       "id": "2",
#       "name": "Math:30000",
#       "totalNumberOfChannels": "21",
#       "numberOfRows": "30000",
#       "channels": [
#         {
#           "name": "Independent",
#           "dataType": "DT_DOUBLE",
#           "unitString": " ",
#           "attributes": {
#             "variables": {
#               "description": {
#                 "stringArray": {
#                   "values": [
#                     "Independent"
#                   ]
#                 }
#               },
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     1
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "1",
#           "name": "Formule 1/Scale_1",
#           "dataType": "DT_DOUBLE",
#           "unitString": "mV/V",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "2",
#           "name": "Formule 2/Binder_weight",
#           "dataType": "DT_DOUBLE",
#           "unitString": "kg",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "3",
#           "name": "Formule 3/Scale_2",
#           "dataType": "DT_DOUBLE",
#           "unitString": "mV/V",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "4",
#           "name": "Formule 4/Fluid_weight",
#           "dataType": "DT_DOUBLE",
#           "unitString": "kg",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "5",
#           "name": "Formule 5/Scale_3",
#           "dataType": "DT_DOUBLE",
#           "unitString": "mV/V",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "6",
#           "name": "Formule 6/Agregaat_weight",
#           "dataType": "DT_DOUBLE",
#           "unitString": "kg",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "7",
#           "name": "Formule 7/Time",
#           "dataType": "DT_DOUBLE",
#           "unitString": "[s]",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "8",
#           "name": "Formule 8/Water_content",
#           "dataType": "DT_DOUBLE",
#           "unitString": "%",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "9",
#           "name": "Formule 11/Compensator",
#           "dataType": "DT_DOUBLE",
#           "unitString": "kg",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "10",
#           "name": "Formule 12/Binder",
#           "dataType": "DT_DOUBLE",
#           "unitString": "kg",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "11",
#           "name": "Formule 13/Agregaat",
#           "dataType": "DT_DOUBLE",
#           "unitString": "kg",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "12",
#           "name": "Formule 14/Water",
#           "dataType": "DT_DOUBLE",
#           "unitString": "kg",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "13",
#           "name": "Formule 15/Binder_ratio",
#           "dataType": "DT_DOUBLE",
#           "unitString": "%",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "14",
#           "name": "Formule 16/Activator_real",
#           "dataType": "DT_DOUBLE",
#           "unitString": "kg",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "15",
#           "name": "Formule 17/Compensator_real",
#           "dataType": "DT_DOUBLE",
#           "unitString": "kg",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "16",
#           "name": "Formule 18/Water_real",
#           "dataType": "DT_DOUBLE",
#           "unitString": "kg",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "17",
#           "name": "Formule 20/Agregaat_ratio",
#           "dataType": "DT_DOUBLE",
#           "unitString": "%",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "18",
#           "name": "Formule 21/wc_high",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "19",
#           "name": "Formule 22/wc_high_soil",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "20",
#           "name": "Formule 23/wc_proc",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         }
#       ]
#     },
#     {
#       "id": "3",
#       "name": "Math:30",
#       "totalNumberOfChannels": "7",
#       "numberOfRows": "30",
#       "channels": [
#         {
#           "name": "Independent",
#           "dataType": "DT_DOUBLE",
#           "unitString": " ",
#           "attributes": {
#             "variables": {
#               "description": {
#                 "stringArray": {
#                   "values": [
#                     "Independent"
#                   ]
#                 }
#               },
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     1
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "1",
#           "name": "Formule 9/volume_ratio",
#           "dataType": "DT_DOUBLE",
#           "unitString": "%",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "2",
#           "name": "Formule 10/Activator",
#           "dataType": "DT_DOUBLE",
#           "unitString": "kg",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "3",
#           "name": "Latch value math 1/Latch index",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "4",
#           "name": "Latch value math 1/Activator_real/Latch",
#           "dataType": "DT_DOUBLE",
#           "unitString": "kg",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "5",
#           "name": "Latch value math 1/Compensator_real/Latch",
#           "dataType": "DT_DOUBLE",
#           "unitString": "kg",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "6",
#           "name": "Latch value math 1/Water_real/Latch",
#           "dataType": "DT_DOUBLE",
#           "unitString": "kg",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         }
#       ]
#     },
#     {
#       "id": "4",
#       "name": "Variables:1",
#       "totalNumberOfChannels": "54",
#       "numberOfRows": "1",
#       "channels": [
#         {
#           "name": "Independent",
#           "dataType": "DT_DOUBLE",
#           "unitString": " ",
#           "attributes": {
#             "variables": {
#               "description": {
#                 "stringArray": {
#                   "values": [
#                     "Independent"
#                   ]
#                 }
#               },
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     1
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "1",
#           "name": "activator_base",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "2",
#           "name": "compensator_base",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "3",
#           "name": "compensator_a",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "4",
#           "name": "compensator_b",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "5",
#           "name": "vol_base",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "6",
#           "name": "binder_base",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "7",
#           "name": "agr_12_14_a",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "8",
#           "name": "agr_12_14_b",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "9",
#           "name": "agr_14_16_a",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "10",
#           "name": "agr_14_16_b",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "11",
#           "name": "agr_0_12_a",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "12",
#           "name": "agr_0_12_b",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "13",
#           "name": "wa_0_12_a",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "14",
#           "name": "wa_0_12_b",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "15",
#           "name": "wa_12_14_a",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "16",
#           "name": "wa_12_14_b",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "17",
#           "name": "wa_14_16_a",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "18",
#           "name": "wa_14_16_b",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "19",
#           "name": "activator_norm",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "20",
#           "name": "ag2",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "21",
#           "name": "ag4",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "22",
#           "name": "ag6",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "23",
#           "name": "ag8",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "24",
#           "name": "ag10",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "25",
#           "name": "ag11_3",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "26",
#           "name": "ag12",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "27",
#           "name": "ag13",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "28",
#           "name": "ag14",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "29",
#           "name": "ag15",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "30",
#           "name": "ag16",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "31",
#           "name": "wa2",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "32",
#           "name": "wa4",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "33",
#           "name": "wa6",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "34",
#           "name": "wa8",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "35",
#           "name": "wa10",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "36",
#           "name": "wa11_3",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "37",
#           "name": "wa12",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "38",
#           "name": "wa14",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "39",
#           "name": "wa15",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "40",
#           "name": "wa16",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "41",
#           "name": "wa13",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "42",
#           "name": "ac2",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "43",
#           "name": "ac14",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "44",
#           "name": "ac15",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "45",
#           "name": "ac16",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "46",
#           "name": "bi2",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "47",
#           "name": "bi14",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "48",
#           "name": "bi15",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "49",
#           "name": "bi16",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "50",
#           "name": "co2",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "51",
#           "name": "co14",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "52",
#           "name": "co15",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "53",
#           "name": "co16",
#           "dataType": "DT_DOUBLE",
#           "attributes": {
#             "variables": {
#               "independent": {
#                 "longArray": {
#                   "values": [
#                     0
#                   ]
#                 }
#               }
#             }
#           }
#         }
#       ]
#     }
#   ],
#   "attributes": {
#     "variables": {
#       "duration": {
#         "doubleArray": {
#           "values": [
#             60.0
#           ]
#         }
#       },
#       "start_time": {
#         "stringArray": {
#           "values": [
#             "20170921074556425002"
#           ]
#         }
#       },
#       "sample_rate": {
#         "doubleArray": {
#           "values": [
#             500.0
#           ]
#         }
#       }
#     }
#   }
# }

# %% [markdown]
# ## Access Bulk Data
#
# With the stored information the ASAM ODS server can access the bulk data from the EXD-API plugin

# %%
with grpc.insecure_channel(exd_api_plugin_url) as channel:
    stub = ods_external_data_pb2_grpc.ExternalDataReaderStub(channel)

    # info from physical storage
    access_group_id = 0
    access_channel_ids = [0, 1, 2, 3]
    access_identifier = ods_external_data_pb2.Identifier(url=access_file_url, parameters=access_file_parameters)

    # open bulk access
    access_handle = stub.Open(access_identifier)
    try:
        request = ods_external_data_pb2.ValuesRequest(
            handle=access_handle, group_id=access_group_id, channel_ids=access_channel_ids
        )

        # read first chunk
        request.start = 0
        request.limit = 2
        values = stub.GetValues(request)
        print(MessageToJson(values))

        # read second chunk
        request.start = 2
        request.limit = 10
        values = stub.GetValues(request)
        print(MessageToJson(values))

    finally:
        stub.Close(access_handle)
# Out:
# {
#   "channels": [
#     {
#       "values": {
#         "dataType": "DT_DOUBLE",
#         "doubleArray": {
#           "values": [
#             1230.0,
#             1230.002
#           ]
#         }
#       }
#     },
#     {
#       "id": "1",
#       "values": {
#         "dataType": "DT_DOUBLE",
#         "doubleArray": {
#           "values": [
#             4958.624243736267,
#             4958.677291870117
#           ]
#         }
#       }
#     },
#     {
#       "id": "2",
#       "values": {
#         "dataType": "DT_DOUBLE",
#         "doubleArray": {
#           "values": [
#             0.44777095317840576,
#             0.4984515905380249
#           ]
#         }
#       }
#     },
#     {
#       "id": "3",
#       "values": {
#         "dataType": "DT_DOUBLE",
#         "doubleArray": {
#           "values": [
#             4965.682029724121,
#             4965.656399726868
#           ]
#         }
#       }
#     }
#   ]
# }
# {
#   "channels": [
#     {
#       "values": {
#         "dataType": "DT_DOUBLE",
#         "doubleArray": {
#           "values": [
#             1230.004,
#             1230.006,
#             1230.008,
#             1230.01,
#             1230.012,
#             1230.014,
#             1230.016,
#             1230.018,
#             1230.02,
#             1230.022
#           ]
#         }
#       }
#     },
#     {
#       "id": "1",
#       "values": {
#         "dataType": "DT_DOUBLE",
#         "doubleArray": {
#           "values": [
#             4958.699345588684,
#             4958.67908000946,
#             4958.672523498535,
#             4958.672523498535,
#             4958.689212799072,
#             4958.636164665222,
#             4958.595633506775,
#             4958.612322807312,
#             4958.641529083252,
#             4958.694577217102
#           ]
#         }
#       }
#     },
#     {
#       "id": "2",
#       "values": {
#         "dataType": "DT_DOUBLE",
#         "doubleArray": {
#           "values": [
#             0.48075854778289795,
#             0.4191935062408447,
#             0.4866594076156616,
#             0.4499995708465576,
#             0.45247673988342285,
#             0.5961495637893677,
#             0.47698020935058594,
#             0.4453742504119873,
#             0.49796581268310547,
#             0.5446553230285645
#           ]
#         }
#       }
#     },
#     {
#       "id": "3",
#       "values": {
#         "dataType": "DT_DOUBLE",
#         "doubleArray": {
#           "values": [
#             4965.620636940002,
#             4965.579509735107,
#             4965.758919715881,
#             4965.6736850738525,
#             4965.750575065613,
#             4965.7779932022095,
#             4965.731501579285,
#             4965.726733207703,
#             4965.6617641448975,
#             4965.648055076599
#           ]
#         }
#       }
#     }
#   ]
# }
