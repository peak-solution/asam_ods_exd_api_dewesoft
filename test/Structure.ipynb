# %% [markdown]
# # Construct the structure

# %%
import dwdatareader as dw
import os
import pathlib

# %% [markdown]
# Get the DwDataReader version

# %% [markdown]
# ## Test that file exists

# %%
example_file = pathlib.Path.absolute(pathlib.Path(r"../data/data_01.dxd"))
if  not os.path.exists(example_file):
    raise ValueError(" File does not exist: " + str(example_file))

# %% [markdown]
# ## Open the file

# %%
print("File to work on: " + str(example_file))
f = dw.open(str(example_file))
# Out:
# File to work on: /workspaces/asam_ods_exd_api_dewesoft/test/../data/data_01.dxd

# %% [markdown]
# ## Get File Info

# %%
info=f.info

store_time  = info.start_store_time;
sample_rate = info.sample_rate
duration    = info.duration

print(f'StartTime  :{store_time}')
print(f'samplerate :{sample_rate}')
print(f'duration   :{duration}')
# Out:
# StartTime  :2017-09-21 07:45:26.445001+00:00
# samplerate :500.0
# duration   :25.0

# %% [markdown]
# ## Number of channels

# %%
number_of_channels=len(f.channels)
print (f'Number of Channels: {number_of_channels}')
# Out:
# Number of Channels: 90

# %% [markdown]
# ## Get group and channel information
# Dictionary from group number to dictionary for channel number to channel

# %%
group_dict={}
channel_dict={}

# %%
chn_number=0
grp_number=0
for ch in f.channels:
    ch_series=ch.series()
    channel_index=ch.channel_index
    group_info=channel_index.split(';')
    group_name=group_info[0]
    if group_name in group_dict:
        channel_dict=group_dict[group_name]["channel_dict"]
        chn_number=chn_number+1
    else:
        # New Group
        chn_number=0
        channel_dict={}
        #Independent Channel
        indep_channel = ch.dataframe().index
        group_dict[group_name]={"channel_dict": channel_dict,"group_number":grp_number,"indep_channel":chn_number}
        grp_number=grp_number+1
        print (f"Independent: {indep_channel}")
        channel_dict[chn_number]={"name":"Index","type":1,"datatype":indep_channel.dtype, "length":len(indep_channel), "description":"Independent","long_name":"Independent","unit":" ","number_of_samples":len(indep_channel)}
        chn_number=chn_number+1        

    chn_length=len(ch_series)
    data_type=ch_series.dtype
    channel_dict[chn_number]={"name":ch.name,"type":ch.channel_type,"datatype":data_type, "length":chn_length, "description":ch.description,"long_name":ch.long_name,"unit":ch.unit,"number_of_samples":ch.number_of_samples}   
    print ("  ArrayInfo        :" + str(ch.arrayInfo))
    print ("  ChannelIndex     :" + str(ch.channel_index))
    print ("  ChannelType      :" + str(ch.channel_type))
    print ("  Fields           :" + str(ch._fields_))
    print ("  ChannelDataFrame :" + str(ch.dataframe))
    print("--"+str(grp_number)+" / "+str(chn_number) +
          "---------------------------------------------------------")
# Out:
#   ArrayInfo        :[]
#   ChannelIndex     :AI;0
#   ChannelType      :0
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff118ff8cd0>>
# --0 / 1---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :AI;1
#   ChannelType      :0
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff118ff82d0>>
# --0 / 2---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :AI;2
#   ChannelType      :0
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff118ff8cd0>>
# --0 / 3---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :AI;3
#   ChannelType      :0
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff118ff82d0>>
# --0 / 4---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :AI;4
#   ChannelType      :0
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff118ff8cd0>>
# --0 / 5---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :AI;5
#   ChannelType      :0
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff118ff82d0>>
# --0 / 6---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :AI;6
#   ChannelType      :0
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff118ff8cd0>>
# --0 / 7---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Plugins;987066259;0
#   ChannelType      :1
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff118ff82d0>>
# --0 / 8---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Plugins;987066259;1
#   ChannelType      :1
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff118ff8cd0>>
# --0 / 9---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Plugins;987066259;2
#   ChannelType      :1
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff118ff82d0>>
# --0 / 10---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Plugins;987066259;3
#   ChannelType      :1
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff118ff8cd0>>
# --0 / 11---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Math;0;0;Output
#   ChannelType      :0
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff118ff82d0>>
# --0 / 12---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Math;1;0;Output
#   ChannelType      :0
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff118ff8450>>
# --0 / 13---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Math;2;0;Output
#   ChannelType      :0
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff15a658750>>
# --0 / 14---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Math;3;0;Output
#   ChannelType      :0
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff118ff82d0>>
# --0 / 15---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Math;4;0;Output
#   ChannelType      :0
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff15a658750>>
# --0 / 16---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Math;5;0;Output
#   ChannelType      :0
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff118ff82d0>>
# --0 / 17---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Math;6;0;Output
#   ChannelType      :0
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff15a658750>>
# --0 / 18---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Math;7;0;Output
#   ChannelType      :0
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff118ff82d0>>
# --0 / 19---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Math;8;0;Output
#   ChannelType      :1
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff15a658750>>
# --0 / 20---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Math;9;0;Output
#   ChannelType      :1
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff118ff89d0>>
# --0 / 21---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Math;10;0;Output
#   ChannelType      :0
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff1598663d0>>
# --0 / 22---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Math;11;0;Output
#   ChannelType      :0
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff159866a50>>
# --0 / 23---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Math;12;0;Output
#   ChannelType      :0
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff1598663d0>>
# --0 / 24---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Math;13;0;Output
#   ChannelType      :0
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff159866a50>>
# --0 / 25---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Math;14;0;Output
#   ChannelType      :0
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff1598663d0>>
# --0 / 26---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Math;15;0;Output
#   ChannelType      :0
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff159866a50>>
# --0 / 27---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Math;16;0;Output
#   ChannelType      :0
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff1598663d0>>
# --0 / 28---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Math;17;0;Output
#   ChannelType      :0
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff159866a50>>
# --0 / 29---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Math;19;0;Output
#   ChannelType      :0
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff1598663d0>>
# --0 / 30---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Math;20;Index
#   ChannelType      :1
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff159866a50>>
# --0 / 31---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Math;20;3;Latch
#   ChannelType      :1
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff1598663d0>>
# --0 / 32---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Math;20;2;Latch
#   ChannelType      :1
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff159866a50>>
# --0 / 33---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Math;20;1;Latch
#   ChannelType      :1
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff1598663d0>>
# --0 / 34---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Math;21;0;Output
#   ChannelType      :0
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff159866a50>>
# --0 / 35---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Math;22;0;Output
#   ChannelType      :0
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff1598663d0>>
# --0 / 36---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Math;23;0;Output
#   ChannelType      :0
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff159866a50>>
# --0 / 37---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;0
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff1598663d0>>
# --0 / 38---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;1
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff159866a50>>
# --0 / 39---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;2
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff1598663d0>>
# --0 / 40---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;3
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff159866a50>>
# --0 / 41---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;4
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff1598663d0>>
# --0 / 42---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;5
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff159866a50>>
# --0 / 43---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;6
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff1598663d0>>
# --0 / 44---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;7
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff159866a50>>
# --0 / 45---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;8
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff1598663d0>>
# --0 / 46---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;9
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff159866a50>>
# --0 / 47---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;10
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff1598663d0>>
# --0 / 48---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;11
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff159866a50>>
# --0 / 49---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;12
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff1598663d0>>
# --0 / 50---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;13
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff159866a50>>
# --0 / 51---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;14
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff1598663d0>>
# --0 / 52---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;15
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff159866a50>>
# --0 / 53---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;16
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff1598663d0>>
# --0 / 54---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;17
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff159866a50>>
# --0 / 55---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;18
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff1598663d0>>
# --0 / 56---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;20
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff159866a50>>
# --0 / 57---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;21
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff1598663d0>>
# --0 / 58---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;22
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff159866a50>>
# --0 / 59---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;23
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff1598663d0>>
# --0 / 60---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;24
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff159866a50>>
# --0 / 61---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;25
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff1598663d0>>
# --0 / 62---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;26
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff159866a50>>
# --0 / 63---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;27
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff1598663d0>>
# --0 / 64---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;28
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff159866a50>>
# --0 / 65---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;29
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff1598663d0>>
# --0 / 66---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;30
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff159866a50>>
# --0 / 67---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;19
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff1598663d0>>
# --0 / 68---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;31
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff159866a50>>
# --0 / 69---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;32
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff1598663d0>>
# --0 / 70---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;33
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff159866a50>>
# --0 / 71---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;34
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff1598663d0>>
# --0 / 72---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;35
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff159866a50>>
# --0 / 73---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;36
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff1598663d0>>
# --0 / 74---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;37
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff159866a50>>
# --0 / 75---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;38
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff1598663d0>>
# --0 / 76---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;39
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff159866a50>>
# --0 / 77---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;40
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff1598663d0>>
# --0 / 78---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;41
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff159866a50>>
# --0 / 79---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;42
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff1598663d0>>
# --0 / 80---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;43
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff159866a50>>
# --0 / 81---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;44
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff1598663d0>>
# --0 / 82---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;45
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff159866a50>>
# --0 / 83---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;46
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff1598663d0>>
# --0 / 84---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;47
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff159866a50>>
# --0 / 85---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;48
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff1598663d0>>
# --0 / 86---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;49
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff159866a50>>
# --0 / 87---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;50
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff1598663d0>>
# --0 / 88---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;51
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff159866a50>>
# --0 / 89---------------------------------------------------------
#   ArrayInfo        :[]
#   ChannelIndex     :Variables;0;52
#   ChannelType      :2
#   Fields           :[('index', <class 'ctypes.c_int'>), ('_name', <class 'dwdatareader.c_char_Array_100'>), ('_unit', <class 'dwdatareader.c_char_Array_20'>), ('_description', <class 'dwdatareader.c_char_Array_200'>), ('color', <class 'ctypes.c_uint'>), ('array_size', <class 'ctypes.c_int'>), ('data_type', <class 'ctypes.c_int'>)]
#   ChannelDataFrame :<bound method DWChannel.dataframe of <dwdatareader.DWChannel object at 0x7ff1598663d0>>
# --0 / 90---------------------------------------------------------

# %% [markdown]
# ## Check structure

# %%
for key, value in group_dict.items():
  print (f"Group Name: {key}, Group Number: {value["group_number"]}")
  chdict=value["channel_dict"]
  for chindex in chdict:
    print (f"  Channel Index: {chindex}, Name: {chdict[chindex]["name"]}, Long Name: {chdict[chindex]["long_name"]}, Lengt: {chdict[chindex]["length"]}, Datatype: {chdict[chindex]["datatype"]}, Unit: {chdict[chindex]["unit"]}")
# Out:
# Group Name: AI, Group Number: 0
#   Channel Index: 0, Name: Index, Long Name: Independent, Lengt: 12500, Datatype: float64, Unit:
#   Channel Index: 1, Name: U_weight1, Long Name: U_weight1, Lengt: 12500, Datatype: float64, Unit: mV
#   Channel Index: 2, Name: S_weight1, Long Name: S_weight1, Lengt: 12500, Datatype: float64, Unit: mV
#   Channel Index: 3, Name: U_weight2, Long Name: U_weight2, Lengt: 12500, Datatype: float64, Unit: mV
#   Channel Index: 4, Name: S_weight2, Long Name: S_weight2, Lengt: 12500, Datatype: float64, Unit: mV
#   Channel Index: 5, Name: U_weight3, Long Name: U_weight3, Lengt: 12500, Datatype: float64, Unit: mV
#   Channel Index: 6, Name: S_weight3, Long Name: S_weight3, Lengt: 12500, Datatype: float64, Unit: mV
#   Channel Index: 7, Name: I_baron1, Long Name: I_baron1, Lengt: 12500, Datatype: float64, Unit: A
# Group Name: Plugins, Group Number: 1
#   Channel Index: 0, Name: Index, Long Name: Independent, Lengt: 0, Datatype: float64, Unit:
#   Channel Index: 1, Name: Mass_wet, Long Name: Mass_wet, Lengt: 13, Datatype: float64, Unit:
#   Channel Index: 2, Name: Mass_dry, Long Name: Mass_dry, Lengt: 13, Datatype: float64, Unit:
#   Channel Index: 3, Name: Volume_tot, Long Name: Volume_tot, Lengt: 13, Datatype: float64, Unit:
#   Channel Index: 4, Name: Takt_time, Long Name: Takt_time, Lengt: 13, Datatype: float64, Unit:
# Group Name: Math, Group Number: 2
#   Channel Index: 0, Name: Index, Long Name: Independent, Lengt: 12500, Datatype: float64, Unit:
#   Channel Index: 1, Name: Scale_1, Long Name: Formule 1/Scale_1, Lengt: 12500, Datatype: float64, Unit: mV/V
#   Channel Index: 2, Name: Binder_weight, Long Name: Formule 2/Binder_weight, Lengt: 12500, Datatype: float64, Unit: kg
#   Channel Index: 3, Name: Scale_2, Long Name: Formule 3/Scale_2, Lengt: 12500, Datatype: float64, Unit: mV/V
#   Channel Index: 4, Name: Fluid_weight, Long Name: Formule 4/Fluid_weight, Lengt: 12500, Datatype: float64, Unit: kg
#   Channel Index: 5, Name: Scale_3, Long Name: Formule 5/Scale_3, Lengt: 12500, Datatype: float64, Unit: mV/V
#   Channel Index: 6, Name: Agregaat_weight, Long Name: Formule 6/Agregaat_weight, Lengt: 12500, Datatype: float64, Unit: kg
#   Channel Index: 7, Name: Time, Long Name: Formule 7/Time, Lengt: 12500, Datatype: float64, Unit: [s]
#   Channel Index: 8, Name: Water_content, Long Name: Formule 8/Water_content, Lengt: 12500, Datatype: float64, Unit: %
#   Channel Index: 9, Name: volume_ratio, Long Name: Formule 9/volume_ratio, Lengt: 13, Datatype: float64, Unit: %
#   Channel Index: 10, Name: Activator, Long Name: Formule 10/Activator, Lengt: 13, Datatype: float64, Unit: kg
#   Channel Index: 11, Name: Compensator, Long Name: Formule 11/Compensator, Lengt: 12500, Datatype: float64, Unit: kg
#   Channel Index: 12, Name: Binder, Long Name: Formule 12/Binder, Lengt: 12500, Datatype: float64, Unit: kg
#   Channel Index: 13, Name: Agregaat, Long Name: Formule 13/Agregaat, Lengt: 12500, Datatype: float64, Unit: kg
#   Channel Index: 14, Name: Water, Long Name: Formule 14/Water, Lengt: 12500, Datatype: float64, Unit: kg
#   Channel Index: 15, Name: Binder_ratio, Long Name: Formule 15/Binder_ratio, Lengt: 12500, Datatype: float64, Unit: %
#   Channel Index: 16, Name: Activator_real, Long Name: Formule 16/Activator_real, Lengt: 12500, Datatype: float64, Unit: kg
#   Channel Index: 17, Name: Compensator_real, Long Name: Formule 17/Compensator_real, Lengt: 12500, Datatype: float64, Unit: kg
#   Channel Index: 18, Name: Water_real, Long Name: Formule 18/Water_real, Lengt: 12500, Datatype: float64, Unit: kg
#   Channel Index: 19, Name: Agregaat_ratio, Long Name: Formule 20/Agregaat_ratio, Lengt: 12500, Datatype: float64, Unit: %
#   Channel Index: 20, Name: Latch index, Long Name: Latch value math 1/Latch index, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 21, Name: Activator_real/Latch, Long Name: Latch value math 1/Activator_real/Latch, Lengt: 1, Datatype: float64, Unit: kg
#   Channel Index: 22, Name: Compensator_real/Latch, Long Name: Latch value math 1/Compensator_real/Latch, Lengt: 1, Datatype: float64, Unit: kg
#   Channel Index: 23, Name: Water_real/Latch, Long Name: Latch value math 1/Water_real/Latch, Lengt: 1, Datatype: float64, Unit: kg
#   Channel Index: 24, Name: wc_high, Long Name: Formule 21/wc_high, Lengt: 12500, Datatype: float64, Unit:
#   Channel Index: 25, Name: wc_high_soil, Long Name: Formule 22/wc_high_soil, Lengt: 12500, Datatype: float64, Unit:
#   Channel Index: 26, Name: wc_proc, Long Name: Formule 23/wc_proc, Lengt: 12500, Datatype: float64, Unit:
# Group Name: Variables, Group Number: 3
#   Channel Index: 0, Name: Index, Long Name: Independent, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 1, Name: activator_base, Long Name: activator_base, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 2, Name: compensator_base, Long Name: compensator_base, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 3, Name: compensator_a, Long Name: compensator_a, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 4, Name: compensator_b, Long Name: compensator_b, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 5, Name: vol_base, Long Name: vol_base, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 6, Name: binder_base, Long Name: binder_base, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 7, Name: agr_12_14_a, Long Name: agr_12_14_a, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 8, Name: agr_12_14_b, Long Name: agr_12_14_b, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 9, Name: agr_14_16_a, Long Name: agr_14_16_a, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 10, Name: agr_14_16_b, Long Name: agr_14_16_b, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 11, Name: agr_0_12_a, Long Name: agr_0_12_a, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 12, Name: agr_0_12_b, Long Name: agr_0_12_b, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 13, Name: wa_0_12_a, Long Name: wa_0_12_a, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 14, Name: wa_0_12_b, Long Name: wa_0_12_b, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 15, Name: wa_12_14_a, Long Name: wa_12_14_a, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 16, Name: wa_12_14_b, Long Name: wa_12_14_b, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 17, Name: wa_14_16_a, Long Name: wa_14_16_a, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 18, Name: wa_14_16_b, Long Name: wa_14_16_b, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 19, Name: activator_norm, Long Name: activator_norm, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 20, Name: ag2, Long Name: ag2, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 21, Name: ag4, Long Name: ag4, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 22, Name: ag6, Long Name: ag6, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 23, Name: ag8, Long Name: ag8, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 24, Name: ag10, Long Name: ag10, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 25, Name: ag11_3, Long Name: ag11_3, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 26, Name: ag12, Long Name: ag12, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 27, Name: ag13, Long Name: ag13, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 28, Name: ag14, Long Name: ag14, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 29, Name: ag15, Long Name: ag15, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 30, Name: ag16, Long Name: ag16, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 31, Name: wa2, Long Name: wa2, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 32, Name: wa4, Long Name: wa4, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 33, Name: wa6, Long Name: wa6, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 34, Name: wa8, Long Name: wa8, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 35, Name: wa10, Long Name: wa10, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 36, Name: wa11_3, Long Name: wa11_3, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 37, Name: wa12, Long Name: wa12, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 38, Name: wa14, Long Name: wa14, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 39, Name: wa15, Long Name: wa15, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 40, Name: wa16, Long Name: wa16, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 41, Name: wa13, Long Name: wa13, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 42, Name: ac2, Long Name: ac2, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 43, Name: ac14, Long Name: ac14, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 44, Name: ac15, Long Name: ac15, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 45, Name: ac16, Long Name: ac16, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 46, Name: bi2, Long Name: bi2, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 47, Name: bi14, Long Name: bi14, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 48, Name: bi15, Long Name: bi15, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 49, Name: bi16, Long Name: bi16, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 50, Name: co2, Long Name: co2, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 51, Name: co14, Long Name: co14, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 52, Name: co15, Long Name: co15, Lengt: 1, Datatype: float64, Unit:
#   Channel Index: 53, Name: co16, Long Name: co16, Lengt: 1, Datatype: float64, Unit:

# %%
print (f['U_weight1'])  
ch1 = f['U_weight1'].series()
print(ch1.dtype)
print(ch1.name)
print(len(ch1))
print(ch1.shape)
print(ch1) # der Wert
# Out:
# U_weight1 (mV)
# float64
# U_weight1
# 12500
# (12500,)
# 1200.020    4958.699346
# 1200.022    4958.738685
# 1200.024    4958.735704
# 1200.026    4958.730340
# 1200.028    4958.778024
#                ...
# 1225.010    4958.673716
# 1225.012    4958.685637
# 1225.014    4958.576560
# 1225.016    4958.590269
# 1225.018    4958.552718
# Name: U_weight1, Length: 12500, dtype: float64

# %%
dataframe1=f['U_weight1'].dataframe()
print(dataframe1)
# Out:
#             U_weight1
# 1200.020  4958.699346
# 1200.022  4958.738685
# 1200.024  4958.735704
# 1200.026  4958.730340
# 1200.028  4958.778024
# ...               ...
# 1225.010  4958.673716
# 1225.012  4958.685637
# 1225.014  4958.576560
# 1225.016  4958.590269
# 1225.018  4958.552718
#
# [12500 rows x 1 columns]

# %%
print(dataframe1.columns)
# Out:
# Index(['U_weight1'], dtype='object')

# %%
print (dataframe1.T)
# Out:
#               1200.020     1200.022     1200.024    1200.026     1200.028  \
# U_weight1  4958.699346  4958.738685  4958.735704  4958.73034  4958.778024
#
#               1200.030     1200.032     1200.034     1200.036    1200.038  \
# U_weight1  4958.691001  4958.713055  4958.685637  4958.497882  4958.57656
#
#            ...     1225.000     1225.002     1225.004     1225.006  \
# U_weight1  ...  4958.677292  4958.691001  4958.624244  4958.714843
#
#               1225.008     1225.010     1225.012    1225.014     1225.016  \
# U_weight1  4958.732128  4958.673716  4958.685637  4958.57656  4958.590269
#
#               1225.018
# U_weight1  4958.552718
#
# [1 rows x 12500 columns]

# %%
print(dataframe1.index) # das ist der Indexkanal, hier Zeit
# Out:
# Index([ 1200.02, 1200.022, 1200.024, 1200.026, 1200.028,  1200.03, 1200.032,
#        1200.034, 1200.036, 1200.038,
#        ...
#          1225.0, 1225.002, 1225.004, 1225.006, 1225.008,  1225.01, 1225.012,
#        1225.014, 1225.016, 1225.018],
#       dtype='float64', length=12500)

# %%
print(dataframe1.index.dtype)
# Out:
# float64

# %%
print(len(dataframe1.index))
# Out:
# 12500

# %%
print(dataframe1.values[12499])
# Out:
# [4958.55271816]

# %%
print(dataframe1.values[0])
# Out:
# [4958.69934559]

# %%
print(dataframe1.values.dtype)
# Out:
# float64

# %%
f.dataframe() #Complete matrix of all channels
# Out:
#             U_weight1  S_weight1    U_weight2  S_weight2    U_weight3  \
# 1200.000          NaN        NaN          NaN        NaN          NaN
# 1200.020  4958.699346   0.593296  4965.871572   1.340941  4971.168041
# 1200.022  4958.738685   0.486376  4965.800047   1.242138  4971.142411
# 1200.024  4958.735704   0.589330  4965.837598   1.338574  4971.103072
# 1200.026  4958.730340   0.578164  4965.866804   1.324176  4971.010685
# ...               ...        ...          ...        ...          ...
# 1225.012  4958.685637   0.460253  4965.658188   1.340706  4971.169829
# 1225.014  4958.576560   0.466467  4965.637922   1.331492  4971.132278
# 1225.016  4958.590269   0.486825  4965.630770   1.346976  4971.164465
# 1225.018  4958.552718   0.447637  4965.774417   1.316698  4971.095920
# 1225.020          NaN        NaN          NaN        NaN          NaN
#
#           S_weight3  I_baron1    Mass_wet   Mass_dry  Volume_tot  ...  ac15  \
# 1200.000        NaN       NaN  113.849998  99.459999        60.0  ...   NaN
# 1200.020   1.488395  2.397387         NaN        NaN         NaN  ...   NaN
# 1200.022   1.385912  1.725335         NaN        NaN         NaN  ...   NaN
# 1200.024   1.480562  1.474922         NaN        NaN         NaN  ...   NaN
# 1200.026   1.468995  0.845535         NaN        NaN         NaN  ...   NaN
# ...             ...       ...         ...        ...         ...  ...   ...
# 1225.012   1.402967  1.624265         NaN        NaN         NaN  ...   NaN
# 1225.014   1.412302  2.816689         NaN        NaN         NaN  ...   NaN
# 1225.016   1.423237  2.583597         NaN        NaN         NaN  ...   NaN
# 1225.018   1.394204  1.841044         NaN        NaN         NaN  ...   NaN
# 1225.020        NaN       NaN         NaN        NaN         NaN  ...  13.0
#
#           ac16   bi2  bi14  bi15  bi16   co2  co14  co15  co16
# 1200.000   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1200.020   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1200.022   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1200.024   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1200.026   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...        ...   ...   ...   ...   ...   ...   ...   ...   ...
# 1225.012   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1225.014   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1225.016   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1225.018   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1225.020  14.5  27.4  27.5  27.8  28.0  10.3  12.6  13.0  14.5
#
# [12502 rows x 90 columns]

# %%
f.close
# Out:
# <bound method DWFile.close of <dwdatareader.DWFile object at 0x7ff11917d6a0>>
